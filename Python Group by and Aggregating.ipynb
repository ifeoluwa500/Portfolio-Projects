# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\THINKPAD T480s\OneDrive\Desktop\ife\Train new.csv")
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %% [raw]
# Count the whole column by the mode of shipment

# %%
df.groupby('Mode_of_Shipment').count()
# Out:
#                     ID  Warehouse_block  Customer_care_calls  Customer_rating  \
# Mode_of_Shipment
# Flight            1777             1777                 1777             1777
# Road              1760             1760                 1760             1760
# Ship              7462             7462                 7462             7462
#
#                   Cost_of_the_Product  Prior_purchases  Product_importance  \
# Mode_of_Shipment
# Flight                           1777             1777                1777
# Road                             1760             1760                1760
# Ship                             7462             7462                7462
#
#                   Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# Mode_of_Shipment
# Flight              1777              1777           1777                 1777
# Road                1760              1760           1760                 1760
# ...

# %% [raw]
# Minimum of all column by mode of shipment

# %%
df.groupby('Mode_of_Shipment').min()
# Out:
#                    ID Warehouse_block  Customer_care_calls  Customer_rating  \
# Mode_of_Shipment
# Flight              1               A                    2                1
# Road              111               A                    2                1
# Ship               18               A                    2                1
#
#                   Cost_of_the_Product  Prior_purchases Product_importance  \
# Mode_of_Shipment
# Flight                             96                2               high
# Road                               97                2               high
# Ship                               96                2               high
#
#                  Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# Mode_of_Shipment
# Flight                F                 1           1001                    0
# Road                  F                 1           1002                    0
# ...

# %% [raw]
# Maximum of all column by mode of shipment

# %%
df.groupby('Mode_of_Shipment').max()
# Out:
#                      ID Warehouse_block  Customer_care_calls  Customer_rating  \
# Mode_of_Shipment
# Flight            10977               F                    7                5
# Road              10955               F                    7                5
# Ship              10999               F                    7                5
#
#                   Cost_of_the_Product  Prior_purchases Product_importance  \
# Mode_of_Shipment
# Flight                            310               10             medium
# Road                              310               10             medium
# Ship                              310               10             medium
#
#                  Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# Mode_of_Shipment
# Flight                M                65           5997                    1
# Road                  M                65           6614                    1
# ...

# %% [raw]
# Sum of all column

# %%
df.groupby('Mode_of_Shipment').sum()
# Out:
#                         ID                                    Warehouse_block  \
# Mode_of_Shipment
# Flight             9776953  DFABCFDFABCFDFABCDFABCFDFABCFDFABCFDFABFDFABCF...
# Road               9738080  ABCFDFABCFDFABCFDFABCFFABCFDFABCFDFABCFDFABCDF...
# Ship              40979467  FDFABCFDFABCFDFABCFDFABCFDFABCFDFABCFDFABCFDFA...
#
#                   Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# Mode_of_Shipment
# Flight                           7293             5300               371938
# Road                             7151             5272               370437
# Ship                            30151            22321              1569580
#
#                   Prior_purchases  \
# Mode_of_Shipment
# Flight                       6338
# Road                         6303
# Ship                        26599
#
#                                                  Product_importance  \
# Mode_of_Shipment
# ...

# %% [raw]
# Aggregate of cost of the product column

# %%
df.groupby('Mode_of_Shipment').agg({'Cost_of_the_Product':['mean', 'max', 'count', 'sum']})
# Out:
#                  Cost_of_the_Product
#                                 mean  max count      sum
# Mode_of_Shipment
# Flight                    209.306697  310  1777   371938
# Road                      210.475568  310  1760   370437
# Ship                      210.343072  310  7462  1569580

# %% [raw]
# Aggregate of all column

# %%
df.groupby('Mode_of_Shipment').describe()
# Out:
#                       ID                                                    \
#                    count         mean          std    min      25%     50%
# Mode_of_Shipment
# Flight            1777.0  5501.943163  3195.316004    1.0  2745.00  5489.0
# Road              1760.0  5533.000000  3164.537793  111.0  2822.00  5533.0
# Ship              7462.0  5491.753819  3173.400797   18.0  2763.25  5508.5
#
#                                    Customer_care_calls            ...  \
#                       75%      max               count      mean  ...
# Mode_of_Shipment                                                  ...
# Flight            8233.00  10977.0              1777.0  4.104108  ...
# Road              8244.00  10955.0              1760.0  4.063068  ...
# Ship              8253.75  10999.0              7462.0  4.040606  ...
#
#                  Weight_in_gms         Reached.on.Time_Y.N            \
#                            75%     max               count      mean
# ...
