# %% [raw]
# Extracting Data from computer with pandas on python

# %%
import pandas as pd

# %%
df =  pd.read_csv(r"C:\Users\THINKPAD T480s\OneDrive\Desktop\ife\Train new.csv")

# %%
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %% [raw]
# Choosong Index: Making the Mode of Shipment the index

# %%
df =  pd.read_csv(r"C:\Users\THINKPAD T480s\OneDrive\Desktop\ife\Train new.csv",index_col="Mode_of_Shipment")

# %%
df
# Out:
#                      ID Warehouse_block  Customer_care_calls  Customer_rating  \
# Mode_of_Shipment
# Flight                1               D                    4                2
# Flight                2               F                    4                5
# Flight                3               A                    2                2
# Flight                4               B                    3                3
# Flight                5               C                    2                2
# ...                 ...             ...                  ...              ...
# Ship              10995               A                    4                1
# Ship              10996               B                    4                1
# Ship              10997               C                    5                4
# Ship              10998               F                    5                2
# Ship              10999               D                    2                5
#
# ...
